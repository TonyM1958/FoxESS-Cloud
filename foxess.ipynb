# %%
import foxess as f
f.get_device()
# Out:
# loading new token
# getting device
# getting firmware
# getting variables
# {'deviceID': 'dcd0712d-3434-40db-9323-933288bc5964',
#  'deviceSN': '65BH602026EB004',
#  'moduleSN': '669L3EPF22WA061',
#  'plantName': '89 Okebourne Park',
#  'deviceType': 'H1-6.0-E',
#  'country': 'United Kingdom',
#  'countryCode': '',
#  'feedinDate': '2023-01-10 15:09:35 GMT+0000',
#  'status': 1,
#  'power': 0.746,
#  'generationToday': 28.5,
#  'generationTotal': 2579.6,
#  'productType': 'H',
#  'flowType': 2,
#  'hasBattery': True,
#  'hasPV': True,
#  'dataLatestUploadDate': '2023-06-14 17:02:46 BST+0100',
#  'hasWifiMeter': False,
#  'inParallel': 0,
#  'wifiMeterID': '',
#  'wifiMeterSN': ''}

# %%
f.get_raw('hour', '2023-05-01 08:00:00')
# Out:
# [{'variable': 'pv1Volt',
#   'unit': 'V',
#   'name': 'PV1Volt',
#   'data': [{'time': '2023-05-01 08:02:36 BST+0100', 'value': 259.3},
#    {'time': '2023-05-01 08:07:37 BST+0100', 'value': 256.5},
#    {'time': '2023-05-01 08:12:37 BST+0100', 'value': 254.2},
#    {'time': '2023-05-01 08:17:37 BST+0100', 'value': 254.9},
#    {'time': '2023-05-01 08:22:37 BST+0100', 'value': 257.2},
#    {'time': '2023-05-01 08:27:37 BST+0100', 'value': 254.1},
#    {'time': '2023-05-01 08:32:37 BST+0100', 'value': 254.9},
#    {'time': '2023-05-01 08:37:37 BST+0100', 'value': 265.3},
#    {'time': '2023-05-01 08:42:37 BST+0100', 'value': 262.1},
#    {'time': '2023-05-01 08:47:37 BST+0100', 'value': 250.6},
#    {'time': '2023-05-01 08:52:37 BST+0100', 'value': 249.4},
#    {'time': '2023-05-01 08:57:37 BST+0100', 'value': 253.5}]},
#  {'variable': 'pv1Current',
#   'unit': 'A',
#   'name': 'PV1Current',
#   'data': [{'time': '2023-05-01 08:02:36 BST+0100', 'value': 2.7},
# ...

# %%
f.get_battery()

# %%
f.var_list
