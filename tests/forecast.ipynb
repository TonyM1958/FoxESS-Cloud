# %% [markdown]
# <h3>Solar Forecast</h3>
#
# Get 13 day solar forecast from your Solcast account / resource ids.

# %%
# run forecast
import private as my
import foxess as f

f.solcast_api_key = my.solcast_api_key
# Out:
# FoxESS-Cloud version 0.6.7

# %%
fsolcast = f.Solcast(estimated=1)
print(fsolcast)
fsolcast.plot_daily()
#fsolcast.plot_hourly()
# Out:
# Using data for 2023-10-02 from solcast.txt
#
# Solcast forecast for 13 days
#    2023-09-26 Tue: 16.31kWh
#    2023-09-27 Wed:  6.17kWh
#    2023-09-28 Thu:  6.90kWh
#    2023-09-29 Fri: 20.61kWh
#    2023-09-30 Sat: 11.57kWh
#    2023-10-01 Sun:  7.20kWh
#    2023-10-02 Mon:  5.82kWh
#    2023-10-03 Tue: 18.61kWh
#    2023-10-04 Wed: 11.28kWh
#    2023-10-05 Thu:  7.80kWh
#    2023-10-06 Fri: 10.11kWh
#    2023-10-07 Sat: 15.46kWh
#    2023-10-08 Sun: 14.58kWh

# %%
f.solar_array('East', lat=51.5477, lon=-1.7353, dec=30, az=260, kwp=3.2, inv=3.6)
f.solar_array('West', lat=51.5477, lon=-1.7353, dec=30, az=80, kwp=3.2, inv=3.6)
fsolar = f.Solar()
print(fsolar)
fsolar.plot_hourly()
# Out:
# Using data for 2023-10-02 from solar.txt
#
# Solar yield for 2 days
#    2023-10-02 Mon :  2.55kWh
#    2023-10-03 Tue : 16.80kWh
