# %% [markdown]
# <h3>Solar Forecast</h3>
#
# Get 13 day solar forecast from your Solcast account / resource ids.

# %%
# run forecast
import private as my
import foxess as f

f.solcast_api_key = my.solcast_api_key
# Out:
# FoxESS-Cloud version 0.5.8

# %%
fsolcast = f.Solcast(estimated=1)
print(fsolcast)
fsolcast.plot_daily()
#fsolcast.plot_hourly()
# Out:
# Getting forecast for 2023-09-23 from solcast.com
#
# Solcast forecast for 13 days
#    2023-09-17 Sun:  5.78 kwh
#    2023-09-18 Mon: 15.67 kwh
#    2023-09-19 Tue:  6.98 kwh
#    2023-09-20 Wed:  3.72 kwh
#    2023-09-21 Thu: 16.55 kwh
#    2023-09-22 Fri: 18.36 kwh
#    2023-09-23 Sat: 22.23 kwh
#    2023-09-24 Sun: 11.11 kwh
#    2023-09-25 Mon: 20.20 kwh
#    2023-09-26 Tue: 14.02 kwh
#    2023-09-27 Wed:  8.85 kwh
#    2023-09-28 Thu: 17.06 kwh
#    2023-09-29 Fri: 15.90 kwh

# %%
f.solar_array('East', lat=51.5477, lon=-1.7353, dec=30, az=260, kwp=3.2, inv=3.6)
f.solar_array('West', lat=51.5477, lon=-1.7353, dec=30, az=80, kwp=3.2, inv=3.6)
fsolar = f.Solar()
print(fsolar)
fsolar.plot_hourly()
# Out:
# Getting data for East array
# Getting data for West array
# Saving data to solar.txt
#
# Solar yield for 2 days
#    2023-09-23 Sat : 18.58 kwh
#    2023-09-24 Sun :  4.23 kwh
