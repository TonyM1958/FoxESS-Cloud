# %% [markdown]
# <h3>Solar Forecast</h3>
#
# Get 13 day solar forecast from your Solcast account / resource ids.

# %%
# run forecast
import private as my
import foxess as f

f.solcast_api_key = my.solcast_api_key
# Out:
# FoxESS-Cloud version 0.7.3

# %%
fsolcast = f.Solcast(estimated=1)
print(fsolcast)
fsolcast.plot_daily()
#fsolcast.plot_hourly()
# Out:
# Using data for 2023-10-08 from solcast.txt
#
# Solcast forecast for 13 days
#    2023-10-02 Mon:  4.31kWh
#    2023-10-03 Tue: 17.77kWh
#    2023-10-04 Wed: 13.82kWh
#    2023-10-05 Thu: 10.31kWh
#    2023-10-06 Fri: 15.70kWh
#    2023-10-07 Sat: 13.70kWh
#    2023-10-08 Sun: 15.68kWh
#    2023-10-09 Mon: 11.19kWh
#    2023-10-10 Tue: 11.69kWh
#    2023-10-11 Wed:  6.82kWh
#    2023-10-12 Thu:  7.89kWh
#    2023-10-13 Fri:  4.58kWh
#    2023-10-14 Sat: 13.51kWh

# %%
f.solar_array('East', lat=51.5477, lon=-1.7353, dec=30, az=260, kwp=3.2, inv=3.6)
f.solar_array('West', lat=51.5477, lon=-1.7353, dec=30, az=80, kwp=3.2, inv=3.6)
fsolar = f.Solar()
print(fsolar)
fsolar.plot_hourly()
# Out:
# Using data for 2023-10-08 from solar.txt
#
# Solar yield for 2 days
#    2023-10-08 Sun : 19.04kWh
#    2023-10-09 Mon :  8.13kWh
