# %% [markdown]
# <h3>Solar Forecast</h3>
#
# Get 13 day solar forecast from your Solcast account / resource ids.

# %%
# run forecast
import private as my
import openapi as f

f.solcast_api_key = my.solcast_api_key
# Out:
# FoxESS-Cloud Open API version 2.0.1

# %%
fsolcast = f.Solcast(estimated=1)
print(fsolcast)
fsolcast.plot_daily()
fsolcast.plot_hourly()
# Out:
# Getting forecast for 2024-02-08 from solcast.com
#
# Solcast forecast for 13 days
#    2024-02-02 Fri:  3.83kWh
#    2024-02-03 Sat:  2.78kWh
#    2024-02-04 Sun:  1.65kWh
#    2024-02-05 Mon:  3.20kWh
#    2024-02-06 Tue:  2.49kWh
#    2024-02-07 Wed:  2.70kWh
#    2024-02-08 Thu:  2.67kWh
#    2024-02-09 Fri:  3.70kWh
#    2024-02-10 Sat:  9.09kWh
#    2024-02-11 Sun:  6.15kWh
#    2024-02-12 Mon:  6.14kWh
#    2024-02-13 Tue:  8.92kWh
#    2024-02-14 Wed: 12.45kWh

# %%
f.solar_array('East', lat=51.5477, lon=-1.7354, dec=30, az=260, kwp=3.2, inv=3.6)
f.solar_array('West', lat=51.5477, lon=-1.7354, dec=30, az=80, kwp=3.2, inv=3.6)
f.debug_setting=2
fsolar = f.Solar()
print(fsolar)
fsolar.plot_hourly()
# Out:
# Getting data for East array
# Getting data for West array
# Saving data to solar.txt
#
# Solar yield for 2 days
#    2024-02-08 Thu :  5.63kWh
#    2024-02-09 Fri :  5.76kWh
