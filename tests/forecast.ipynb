# %% [markdown]
# <h3>Solar Forecast</h3>
#
# Get 13 day solar forecast from your Solcast account / resource ids.

# %%
# run forecast
import private as my
import foxess as f

f.solcast_api_key = my.solcast_api_key
# Out:
# FoxESS-Cloud version 0.8.4

# %%
fsolcast = f.Solcast(estimated=1)
print(fsolcast)
fsolcast.plot_daily()
fsolcast.plot_hourly()
# Out:
# Using data for 2023-10-24 from solcast.txt
#
# Solcast forecast for 13 days
#    2023-10-18 Wed:  4.35kWh
#    2023-10-19 Thu:  5.92kWh
#    2023-10-20 Fri:  8.75kWh
#    2023-10-21 Sat:  5.49kWh
#    2023-10-22 Sun: 14.32kWh
#    2023-10-23 Mon:  8.99kWh
#    2023-10-24 Tue: 14.01kWh
#    2023-10-25 Wed:  8.78kWh
#    2023-10-26 Thu:  9.24kWh
#    2023-10-27 Fri:  9.07kWh
#    2023-10-28 Sat:  7.58kWh
#    2023-10-29 Sun:  6.80kWh
#    2023-10-30 Mon:  8.12kWh

# %%
f.solar_array('East', lat=51.5477, lon=-1.7353, dec=30, az=260, kwp=3.2, inv=3.6)
f.solar_array('West', lat=51.5477, lon=-1.7353, dec=30, az=80, kwp=3.2, inv=3.6)
fsolar = f.Solar()
print(fsolar)
fsolar.plot_hourly()
# Out:
# Using data for 2023-10-24 from solar.txt
#
# Solar yield for 2 days
#    2023-10-24 Tue :  9.25kWh
#    2023-10-25 Wed :  4.60kWh
